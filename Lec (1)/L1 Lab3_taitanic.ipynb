# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
y = df["Survived"]
x = df[["Pclass","Sex","Age","Fare"]]
x
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
# prompt: map male and female
x['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
x
# Out:
# <ipython-input-11-f8d46d781b23>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Sex'] = df['Sex'].map({'male': 0, 'female': 1})
#      Pclass  Sex   Age     Fare
# 0         3    0  22.0   7.2500
# 1         1    1  38.0  71.2833
# 2         3    1  26.0   7.9250
# 3         1    1  35.0  53.1000
# 4         3    0  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    0  27.0  13.0000
# 887       1    1  19.0  30.0000
# 888       3    1   NaN  23.4500
# 889       1    0  26.0  30.0000
# 890       3    0  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
x.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age       177
# Fare        0
# dtype: int64

# %%
# prompt: want to remove empty age rows from the dataframe x
x.dropna(subset=['Age'], inplace=True)
x
# Out:
# <ipython-input-13-04ca3e0117fe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.dropna(subset=['Age'], inplace=True)
#      Pclass  Sex   Age     Fare
# 0         3    0  22.0   7.2500
# 1         1    1  38.0  71.2833
# 2         3    1  26.0   7.9250
# 3         1    1  35.0  53.1000
# 4         3    0  35.0   8.0500
# ..      ...  ...   ...      ...
# 885       3    1  39.0  29.1250
# 886       2    0  27.0  13.0000
# 887       1    1  19.0  30.0000
# 889       1    0  26.0  30.0000
# 890       3    0  32.0   7.7500
#
# [714 rows x 4 columns]

# %%
# prompt: cheak if there is any missing value in y

y.isnull().sum()
# Out:
# np.int64(0)

# %%
# prompt: split the data =fa=rame x and y into two sets for train and test
# Reset index of y to match x after dropping rows with missing values:
y = y[x.index]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_test
# Out:
#      Pclass  Sex   Age     Fare
# 149       2    0  42.0  13.0000
# 407       2    0   3.0  18.7500
# 53        2    1  29.0  26.0000
# 369       1    1  24.0  69.3000
# 818       3    0  43.0   6.4500
# ..      ...  ...   ...      ...
# 819       3    0  10.0  27.9000
# 164       3    0   1.0  39.6875
# 363       3    0  35.0   7.0500
# 56        2    1  21.0  10.5000
# 136       1    1  19.0  26.2833
#
# [143 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
# prompt: read housing file , the seperate here is not csv its spaces
data = pd.read_csv('housing.csv', delim_whitespace=True)
data
# Out:
# <ipython-input-2-151e62c756c3>:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv('housing.csv', delim_whitespace=True)
#      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0    0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1    0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2    0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3    0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4    0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
# ..       ...    ...    ... ..     ...     ...    ...     ... ..    ...    ...
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# ...

# %%
data.isnull().sum()
# Out:
# 0.00632    0
# 18.00      0
# 2.310      0
# 0          0
# 0.5380     0
# 6.5750     0
# 65.20      0
# 4.0900     0
# 1          0
# 296.0      0
# 15.30      0
# 396.90     0
# 4.98       0
# 24.00      0
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0    0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1    0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2    0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3    0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4    0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
# ..       ...    ...    ... ..     ...     ...    ...     ... ..    ...    ...
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# 502  0.06076    0.0  11.93  0   0.573   6.976   91.0  2.1675  1  273.0   21.0
# 503  0.10959    0.0  11.93  0   0.573   6.794   89.3  2.3889  1  273.0   21.0
# 504  0.04741    0.0  11.93  0   0.573   6.030   80.8  2.5050  1  273.0   21.0
#
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  296.0  15.30  \
# 0    0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2  242.0   17.8
# 1    0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2  242.0   17.8
# 2    0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3  222.0   18.7
# 3    0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3  222.0   18.7
# 4    0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3  222.0   18.7
# ..       ...    ...    ... ..     ...     ...    ...     ... ..    ...    ...
# 500  0.06263    0.0  11.93  0   0.573   6.593   69.1  2.4786  1  273.0   21.0
# 501  0.04527    0.0  11.93  0   0.573   6.120   76.7  2.2875  1  273.0   21.0
# 502  0.06076    0.0  11.93  0   0.573   6.976   91.0  2.1675  1  273.0   21.0
# 503  0.10959    0.0  11.93  0   0.573   6.794   89.3  2.3889  1  273.0   21.0
# 504  0.04741    0.0  11.93  0   0.573   6.030   80.8  2.5050  1  273.0   21.0
#
# ...

# %%
X = data.drop('24.00', axis = 1)
y = data['24.00']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test
# Out:
#      0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  \
# 173  0.08447    0.0   4.05  0   0.510   5.859   68.7  2.7019   5  296.0
# 274  0.09604   40.0   6.41  0   0.447   6.854   42.8  4.2673   4  254.0
# 490  0.10574    0.0  27.74  0   0.609   5.983   98.8  1.8681   4  711.0
# 72   0.19539    0.0  10.81  0   0.413   6.245    6.2  5.2873   4  305.0
# 305  0.07503   33.0   2.18  0   0.472   7.420   71.9  3.0992   7  222.0
# ..       ...    ...    ... ..     ...     ...    ...     ...  ..    ...
# 440  9.72418    0.0  18.10  0   0.740   6.406   97.2  2.0651  24  666.0
# 23   0.75026    0.0   8.14  0   0.538   5.924   94.1  4.3996   4  307.0
# 225  0.38214    0.0   6.20  0   0.504   8.040   86.5  3.2157   8  307.0
# 432  5.58107    0.0  18.10  0   0.713   6.436   87.9  2.3158  24  666.0
# 446  9.92485    0.0  18.10  0   0.740   6.251   96.6  2.1980  24  666.0
#
#      15.30  396.90   4.98
# 173   16.6  393.23   9.64
# 274   17.6  396.90   2.98
# ...

# %%
# prompt: linear regression and name it model 1 with r2 score for train and test

model1 = LinearRegression()
model1.fit(X_train, y_train)

y_train_pred = model1.predict(X_train)
y_test_pred = model1.predict(X_test)

r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f"R2 score on training data: {r2_train:.4f}")
print(f"R2 score on testing data: {r2_test:.4f}")
# Out:
# R2 score on training data: 0.7433
# R2 score on testing data: 0.7093

# %%
# prompt: polynomial featrue

poly_features = PolynomialFeatures(degree=2)

X_train_poly = poly_features.fit_transform(X_train)
X_test_poly = poly_features.transform(X_test)

model2 = LinearRegression()
model2.fit(X_train_poly, y_train)

y_train_pred_poly = model2.predict(X_train_poly)
y_test_pred_poly = model2.predict(X_test_poly)

r2_train_poly = r2_score(y_train, y_train_pred_poly)
r2_test_poly = r2_score(y_test, y_test_pred_poly)

print(f"R2 score with Polynomial Features (degree 2) on training data: {r2_train_poly:.4f}")
print(f"R2 score with Polynomial Features (degree 2) on testing data: {r2_test_poly:.4f}")
# Out:
# R2 score with Polynomial Features (degree 2) on training data: 0.9391
# R2 score with Polynomial Features (degree 2) on testing data: 0.8285

# %%
# prompt: lasso regression on polynomial model

from sklearn.linear_model import Lasso

# Lasso regression with polynomial features
lasso_model = Lasso(alpha=0.1) # You can adjust the alpha parameter

lasso_model.fit(X_train_poly, y_train)

y_train_pred_lasso = lasso_model.predict(X_train_poly)
y_test_pred_lasso = lasso_model.predict(X_test_poly)

r2_train_lasso = r2_score(y_train, y_train_pred_lasso)
r2_test_lasso = r2_score(y_test, y_test_pred_lasso)

print(f"\nR2 score with Lasso Regression (Polynomial Features) on training data: {r2_train_lasso:.4f}")
print(f"R2 score with Lasso Regression (Polynomial Features) on testing data: {r2_test_lasso:.4f}")
# Out:
# R2 score with Lasso Regression (Polynomial Features) on training data: 0.9118
# R2 score with Lasso Regression (Polynomial Features) on testing data: 0.7977
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.638e+03, tolerance: 3.246e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# prompt: ridge regression

from sklearn.linear_model import Ridge

# Ridge regression with polynomial features
ridge_model = Ridge(alpha=0.1) # You can adjust the alpha parameter

ridge_model.fit(X_train_poly, y_train)

y_train_pred_ridge = ridge_model.predict(X_train_poly)
y_test_pred_ridge = ridge_model.predict(X_test_poly)

r2_train_ridge = r2_score(y_train, y_train_pred_ridge)
r2_test_ridge = r2_score(y_test, y_test_pred_ridge)

print(f"\nR2 score with Ridge Regression (Polynomial Features) on training data: {r2_train_ridge:.4f}")
print(f"R2 score with Ridge Regression (Polynomial Features) on testing data: {r2_test_ridge:.4f}")
# Out:
# R2 score with Ridge Regression (Polynomial Features) on training data: 0.9375
# R2 score with Ridge Regression (Polynomial Features) on testing data: 0.8171

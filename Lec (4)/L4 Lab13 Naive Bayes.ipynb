# %%
# linux command to move the data from uploaded file to dataset file
#!mkdir dataset
#!mv *.csv dataset/
#!ls dataset/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

# %%
# glob output
path = r"/content/dataset"
allfiles = glob.glob(path + "/*.csv")
allfiles
# Out:
# ['/content/dataset/Youtube03-LMFAO.csv',
#  '/content/dataset/Youtube05-Shakira.csv',
#  '/content/dataset/Youtube02-KatyPerry.csv',
#  '/content/dataset/Youtube04-Eminem.csv',
#  '/content/dataset/Youtube01-Psy.csv']

# %%
path = r"/content/dataset"
allfiles = glob.glob(path + "/*.csv")
fram = pd.DataFrame()
list_ = []
for file_ in allfiles:
    df = pd.read_csv(file_, index_col=None, header=0)
    list_.append(df)
fram = pd.concat(list_, axis=0, ignore_index=True)
frame = fram

# %%
frame.shape
# Out:
# (1956, 5)

# %%
df = frame.iloc[:,3:5]
df
# Out:
#                                                 CONTENT  CLASS
# 0     <a href="http://www.youtube.com/watch?v=KQ6zr6...      0
# 1                                      wierd but funny﻿      0
# 2     Hey guys, I&#39;m a human.<br /><br /><br />Bu...      1
# 3          Party Rock....lol...who wants to shuffle!!!﻿      0
# 4                                           Party rock﻿      0
# ...                                                 ...    ...
# 1951  How can this have 2 billion views when there's...      0
# 1952         I don't now why I'm watching this in 2014﻿      0
# 1953  subscribe to me for call of duty vids and give...      1
# 1954  hi guys please my android photo editor downloa...      1
# 1955  The first billion viewed this because they tho...      0
#
# [1956 rows x 2 columns]

# %%
x = df["CONTENT"]
y = df["CLASS"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=53)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1369,) (587,) (1369,) (587,)

# %%
count_vectorizer = CountVectorizer(stop_words="english")
count_train = count_vectorizer.fit_transform(x_train.values) # fit transform only for first time
count_test = count_vectorizer.transform(x_test.values) # just transform because we want to use the sha[e of the first size not new one
print(count_train.shape)
print(count_test.shape)
# Out:
# (1369, 3400)
# (587, 3400)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
model = MultinomialNB()
model.fit(count_train, y_train)
pred = model.predict(count_test)
score = metrics.accuracy_score(y_test, pred)
print("accuracy: %0.3f" % score)
# Out:
# accuracy: 0.899

# %%
dataset = ["i love this movie"] # your opinion
dataset1 = pd.DataFrame(dataset)
dataset1[0]
count_test = count_vectorizer.transform(dataset1[0].values)
model.predict(count_test)
# Out:
# array([0])
